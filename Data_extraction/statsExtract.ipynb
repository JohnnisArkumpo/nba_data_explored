# %%
import pandas as pd

dtb = '~/code/nba_data_explored/Data_extraction/PlayerStatistics.parquet'

df = pd.read_parquet(dtb)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1632123 entries, 0 to 1632122
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   firstName                1632123 non-null  str
#  1   lastName                 1632123 non-null  str
#  2   personId                 1632123 non-null  int64
#  3   gameId                   1632123 non-null  int64
#  4   gameDate                 1632123 non-null  str
#  5   playerteamCity           1632123 non-null  str
#  6   playerteamName           1632123 non-null  str
#  7   opponentteamCity         1632123 non-null  str
#  8   opponentteamName         1632123 non-null  str
#  9   gameType                 1627800 non-null  str
#  10  gameLabel                93332 non-null    str
#  11  gameSubLabel             4817 non-null     str
#  12  seriesGameNumber         135048 non-null   float64
#  13  win                      1632123 non-null  int64
# ...
